# %% [markdown]
# # MTA Turnstile Data Exploratory Data Analysis
#
# Initial Exploratory Data Analysis on smaller sample of data

# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# Focus just on 3 weeks worth of data
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [210109, 210116, 210123]
df = get_data(week_nums)

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7511653
# 1  REGULAR  7511655
# 2  REGULAR  7511677
# 3  REGULAR  7511766
# 4  REGULAR  7511912
#
#    EXITS
# 0                                            2558871
# 1                                            2558877
# 2                                            2558930
# 3                                            2558968
# 4                                            2558999

# %%
print(df.dtypes)
print(df.columns)
print(df.shape)
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')
# (628892, 11)

# %% [markdown]
# ### Data Cleaning
# **1. Identifying problems with the dataset**
#    - Extra whitespace in EXITS column
#    - Inconsistent datatype:
#        - DATE, TIME (datetime object)
#        - ENTRIES, EXITS (int)
#    - Any Missing Values
#    - Any duplicates of the same datetime
#    - Drop any unnecessary columns or rows

# %%
# rename columns to remove whitespace
df.columns = [column.strip() for column in df.columns]
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
from datetime import datetime, timedelta
# Create DATETIME column from DATE, TIME columns
df['DATETIME'] = pd.to_datetime(df['DATE'] + " " + df['TIME'],
                                   format="%m/%d/%Y %H:%M:%S")
# Create DAY_OF_WEEK column from DATETIME
df['DAY_OF_WEEK'] = df[['DATETIME']]\
    .apply(lambda x: datetime.strftime(x['DATETIME'], "%A"), axis=1)

# %%
#change dtypes
df['ENTRIES']=df.ENTRIES.astype('int')
df['EXITS']=df.EXITS.astype('int')

# %%
#Checking for duplicates 
(df
.groupby(['C/A','UNIT','SCP','STATION','DATE','TIME'])
.ENTRIES.count()
.reset_index()
.sort_values("ENTRIES", ascending=False)).head()
# Out:
#          C/A  UNIT       SCP         STATION        DATE      TIME  ENTRIES
# 308795  N512  R163  00-00-00           14 ST  01/15/2021  11:00:00        2
# 56629   B028  R136  01-00-01  SHEEPSHEAD BAY  01/08/2021  04:00:00        2
# 0       A002  R051  02-00-00           59 ST  01/02/2021  03:00:00        1
# 419264  R138  R293  00-02-05  34 ST-PENN STA  01/02/2021  17:00:00        1
# 419258  R138  R293  00-02-04  34 ST-PENN STA  01/22/2021  17:00:00        1

# %%
#double checking on 01/15/21, seems to be double entries which does not affect the regular entry
mask = ((df['C/A'] == 'N512') &
       (df['UNIT'] == 'R163') &
       (df['SCP'] == '00-00-00') &
       (df['STATION'] == '14 ST') &
       (df['DATE'] == "01/15/2021"))
df[mask]
# Out:
#          C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 102924  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  03:00:00
# 102925  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  07:00:00
# 102926  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  11:00:00
# 102927  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  11:00:00
# 102928  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  15:00:00
# 102929  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  19:00:00
# 102930  N512  R163  00-00-00   14 ST   FLM123      IND  01/15/2021  23:00:00
#
#               DESC  ENTRIES    EXITS            DATETIME DAY_OF_WEEK
# 102924     REGULAR  3755758  8020534 2021-01-15 03:00:00      Friday
# 102925     REGULAR  3755762  8020550 2021-01-15 07:00:00      Friday
# 102926     REGULAR  3755777  8020627 2021-01-15 11:00:00      Friday
# 102927  RECOVR AUD        4        0 2021-01-15 11:00:00      Friday
# 102928     REGULAR  3755807  8020684 2021-01-15 15:00:00      Friday
# 102929     REGULAR  3755860  8020748 2021-01-15 19:00:00      Friday
# 102930     REGULAR  3755878  8020763 2021-01-15 23:00:00      Friday

# %%
df.DESC.value_counts()
# Out:
# REGULAR       626747
# RECOVR AUD      2145
# Name: DESC, dtype: int64

# %%
# Appears there are extra entries from RECOVR AUD, which are not relevant 
# for the analysis
# Remove non-REGULAR values from 'DESC'
df = df.drop(df.loc[df.DESC != 'REGULAR'].index)

# %%
#Sanity Check again
(df
.groupby(['C/A','UNIT','SCP','STATION','DATE','TIME'])
.ENTRIES.count()
.reset_index()
.sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#          C/A  UNIT       SCP         STATION        DATE      TIME  ENTRIES
# 0       A002  R051  02-00-00           59 ST  01/02/2021  03:00:00        1
# 414977  R138  R293  00-02-01  34 ST-PENN STA  01/16/2021  13:00:00        1
# 414979  R138  R293  00-02-01  34 ST-PENN STA  01/16/2021  21:00:00        1
# 414980  R138  R293  00-02-01  34 ST-PENN STA  01/17/2021  01:00:00        1
# 414981  R138  R293  00-02-01  34 ST-PENN STA  01/17/2021  05:00:00        1

# %%
#Drop rows for PATH, RIT, and SRT 
#since only checking on subway data
df.drop(df.loc[df['DIVISION'].isin(['PTH','RIT','SRT'])].index, 
        inplace=True)
df.shape
# Out:
# (572172, 13)

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/02/2021  19:00:00
#
#       DESC  ENTRIES    EXITS            DATETIME DAY_OF_WEEK
# 0  REGULAR  7511653  2558871 2021-01-02 03:00:00    Saturday
# 1  REGULAR  7511655  2558877 2021-01-02 07:00:00    Saturday
# 2  REGULAR  7511677  2558930 2021-01-02 11:00:00    Saturday
# 3  REGULAR  7511766  2558968 2021-01-02 15:00:00    Saturday
# 4  REGULAR  7511912  2558999 2021-01-02 19:00:00    Saturday

# %%
# Drop unnecessary columns
df = df.drop(['LINENAME', 'DIVISION', 'DESC', 'DATE', 'TIME'], axis=1)
df.head()
# Out:
#     C/A  UNIT       SCP STATION  ENTRIES    EXITS            DATETIME  \
# 0  A002  R051  02-00-00   59 ST  7511653  2558871 2021-01-02 03:00:00
# 1  A002  R051  02-00-00   59 ST  7511655  2558877 2021-01-02 07:00:00
# 2  A002  R051  02-00-00   59 ST  7511677  2558930 2021-01-02 11:00:00
# 3  A002  R051  02-00-00   59 ST  7511766  2558968 2021-01-02 15:00:00
# 4  A002  R051  02-00-00   59 ST  7511912  2558999 2021-01-02 19:00:00
#
#   DAY_OF_WEEK
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday

# %%
# Detecting any missing values
df.isna().sum()
# Out:
# C/A            0
# UNIT           0
# SCP            0
# STATION        0
# ENTRIES        0
# EXITS          0
# DATETIME       0
# DAY_OF_WEEK    0
# dtype: int64

# %%
# Checking on first formatted dataset
df.sort_values(['C/A', 'UNIT', 'SCP', 'STATION', 'DATETIME'],
              inplace=True, ascending=True)
print(df.shape)
df.head()
# Out:
# (572172, 8)
#     C/A  UNIT       SCP STATION  ENTRIES    EXITS            DATETIME  \
# 0  A002  R051  02-00-00   59 ST  7511653  2558871 2021-01-02 03:00:00
# 1  A002  R051  02-00-00   59 ST  7511655  2558877 2021-01-02 07:00:00
# 2  A002  R051  02-00-00   59 ST  7511677  2558930 2021-01-02 11:00:00
# 3  A002  R051  02-00-00   59 ST  7511766  2558968 2021-01-02 15:00:00
# 4  A002  R051  02-00-00   59 ST  7511912  2558999 2021-01-02 19:00:00
#
#   DAY_OF_WEEK
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday

# %% [markdown]
# **2. Entry and Exit counts**
#    - some counters resets or count backwards

# %%
#Create previous datetime, entries and entries columns
df[['PREV_DATETIME', "PREV_ENTRIES", "PREV_EXITS"]] = (df
                                                .groupby(['C/A', 'UNIT', 'SCP', 'STATION'])\
                                                       ['DATETIME','ENTRIES','EXITS']
                                                .apply(lambda grp: grp.shift(1)))
# Out:
# <ipython-input-18-15cd4dd5a8ea>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df[['PREV_DATETIME', "PREV_ENTRIES", "PREV_EXITS"]] = (df

# %%
# Drop the rows for the earliest times in the df
df.dropna(subset=["PREV_DATETIME"], axis=0, inplace=True)
df.head()
# Out:
#     C/A  UNIT       SCP STATION  ENTRIES    EXITS            DATETIME  \
# 1  A002  R051  02-00-00   59 ST  7511655  2558877 2021-01-02 07:00:00
# 2  A002  R051  02-00-00   59 ST  7511677  2558930 2021-01-02 11:00:00
# 3  A002  R051  02-00-00   59 ST  7511766  2558968 2021-01-02 15:00:00
# 4  A002  R051  02-00-00   59 ST  7511912  2558999 2021-01-02 19:00:00
# 5  A002  R051  02-00-00   59 ST  7511996  2559007 2021-01-02 23:00:00
#
#   DAY_OF_WEEK       PREV_DATETIME  PREV_ENTRIES  PREV_EXITS
# 1    Saturday 2021-01-02 03:00:00     7511653.0   2558871.0
# 2    Saturday 2021-01-02 07:00:00     7511655.0   2558877.0
# 3    Saturday 2021-01-02 11:00:00     7511677.0   2558930.0
# 4    Saturday 2021-01-02 15:00:00     7511766.0   2558968.0
# 5    Saturday 2021-01-02 19:00:00     7511912.0   2558999.0

# %%
# problem with counter being in reverse
df[df["ENTRIES"] < df["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP     STATION    ENTRIES      EXITS  \
# 1639  A011  R080  01-03-00  57 ST-7 AV  885629549  489699476
# 1640  A011  R080  01-03-00  57 ST-7 AV  885629539  489699340
# 1641  A011  R080  01-03-00  57 ST-7 AV  885629523  489699138
# 1642  A011  R080  01-03-00  57 ST-7 AV  885629468  489698994
# 1643  A011  R080  01-03-00  57 ST-7 AV  885629436  489698939
#
#                 DATETIME DAY_OF_WEEK       PREV_DATETIME  PREV_ENTRIES  \
# 1639 2021-01-02 07:00:00    Saturday 2021-01-02 03:00:00   885629550.0
# 1640 2021-01-02 11:00:00    Saturday 2021-01-02 07:00:00   885629549.0
# 1641 2021-01-02 15:00:00    Saturday 2021-01-02 11:00:00   885629539.0
# 1642 2021-01-02 19:00:00    Saturday 2021-01-02 15:00:00   885629523.0
# 1643 2021-01-02 23:00:00    Saturday 2021-01-02 19:00:00   885629468.0
#
#        PREV_EXITS
# 1639  489699496.0
# 1640  489699476.0
# 1641  489699340.0
# 1642  489699138.0
# 1643  489698994.0

# %%
# Let's see how many stations have this problem
(df[df["ENTRIES"] < df["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A   UNIT  SCP       STATION
# A011  R080  01-03-00  57 ST-7 AV         125
# A031  R083  00-00-01  23 ST                1
# A042  R086  01-00-04  PRINCE ST            2
# A043  R462  00-03-03  CANAL ST             1
# A049  R088  02-05-00  CORTLANDT ST         7
#                                         ...
# R401  R445  00-00-00  3 AV 138 ST        122
# R412  R146  00-00-00  HUNTS POINT AV      70
# R523  R147  00-00-04  61 ST WOODSIDE     111
# R622  R123  00-00-00  FRANKLIN AV        123
# R730  R431  00-00-04  EASTCHSTER/DYRE     34
# Length: 71, dtype: int64

# %%
# Functions for entry and exit counts
def get_entry_counts(row, max_counter):
    counter = abs(row['ENTRIES'] - row['PREV_ENTRIES'])
    # Set anomaly values due to reset of counters to the uniform NaN values
    if counter > max_counter:
        counter = np.nan
    return counter

def get_exit_counts(row, max_counter):
    counter = abs(row['EXITS'] - row['PREV_EXITS'])
    # Set anomaly values due to reset of counters to the uniform NaN values
    if counter > max_counter:
        counter = np.nan
    return counter

# Set max_counter = 86400, assuming only 1/person/sec/turnstile at a time
df['entry_count'] = df.apply(get_entry_counts, axis=1, max_counter=14400)
df['exit_count'] = df.apply(get_exit_counts, axis=1, max_counter=14400)
df.head()
# Out:
#     C/A  UNIT       SCP STATION  ENTRIES    EXITS            DATETIME  \
# 1  A002  R051  02-00-00   59 ST  7511655  2558877 2021-01-02 07:00:00
# 2  A002  R051  02-00-00   59 ST  7511677  2558930 2021-01-02 11:00:00
# 3  A002  R051  02-00-00   59 ST  7511766  2558968 2021-01-02 15:00:00
# 4  A002  R051  02-00-00   59 ST  7511912  2558999 2021-01-02 19:00:00
# 5  A002  R051  02-00-00   59 ST  7511996  2559007 2021-01-02 23:00:00
#
#   DAY_OF_WEEK       PREV_DATETIME  PREV_ENTRIES  PREV_EXITS  entry_count  \
# 1    Saturday 2021-01-02 03:00:00     7511653.0   2558871.0          2.0
# 2    Saturday 2021-01-02 07:00:00     7511655.0   2558877.0         22.0
# 3    Saturday 2021-01-02 11:00:00     7511677.0   2558930.0         89.0
# 4    Saturday 2021-01-02 15:00:00     7511766.0   2558968.0        146.0
# 5    Saturday 2021-01-02 19:00:00     7511912.0   2558999.0         84.0
#
#    exit_count
# 1         6.0
# 2        53.0
# 3        38.0
# 4        31.0
# 5         8.0

# %%
# Checking NaN values created by previous function
# NaN values are counters that are negative or exceeds threshold
print("NaN in Entry: ", df.entry_count.isna().sum())
print("NaN in Exit: ", df.entry_count.isna().sum())
# Out:
# NaN in Entry:  26
# NaN in Exit:  26

# %%
df[df.entry_count.isna() == 1].head()
# Out:
#         C/A  UNIT       SCP          STATION  ENTRIES  EXITS  \
# 4717   A031  R083  00-00-01            23 ST       16     12
# 7306   A043  R462  00-03-03         CANAL ST        2      8
# 10857  A058  R001  01-00-01  WHITEHALL S-FRY       32     25
# 14970  B015  R098  01-03-00        CHURCH AV   196632      8
# 29663  E011  R371  00-06-01            79 ST   262158     19
#
#                  DATETIME DAY_OF_WEEK       PREV_DATETIME  PREV_ENTRIES  \
# 4717  2021-01-17 11:00:00      Sunday 2021-01-16 03:00:00     5102094.0
# 7306  2021-01-10 12:00:00      Sunday 2021-01-10 08:00:00      196944.0
# 10857 2021-01-11 12:00:00      Monday 2021-01-11 08:00:00     2172459.0
# 14970 2021-01-22 11:00:00      Friday 2021-01-21 19:00:00       13806.0
# 29663 2021-01-07 15:00:00    Thursday 2021-01-07 11:00:00      526761.0
#
#        PREV_EXITS  entry_count  exit_count
# 4717    1719658.0          NaN         NaN
# 7306     155111.0          NaN         NaN
# 10857   1717560.0          NaN         NaN
# 14970     14983.0          NaN         NaN
# 29663      2570.0          NaN      2551.0

# %%
# Fill NaN values with the mean of values before and after NaN value
# AKA take the mean of the daily count

entry_list = list(df['entry_count'])
ind = 0
for i in entry_list:
    if np.isnan(i) == 1:
        entry_list[ind] = np.nanmean([entry_list[ind-2],entry_list[ind-1],entry_list[ind+1],entry_list[ind+2]])
    ind += 1
    
df['ENTRY_DIFF'] = entry_list

# %%
df['ENTRY_DIFF'].isna().sum()
# Out:
# 0

# %%
# Cleaning NaN values in exit_count
# For each NaN values, replace it with the mean of values 
                                        #before and after the NaN value
exit_list = list(df['exit_count'])
ind = 0
for i in exit_list:
    if np.isnan(i) == 1:
        exit_list[ind] = np.nanmean([exit_list[ind-2],exit_list[ind-1],exit_list[ind+1],exit_list[ind+2]])
    ind += 1
    
df['EXIT_DIFF'] = exit_list

# %%
df['EXIT_DIFF'].isna().sum()
# Out:
# 0

# %%
# Get total traffic count
df['TOTAL_TRAFFIC'] = df['ENTRY_DIFF'] + df['EXIT_DIFF']
df.head()
# Out:
#     C/A  UNIT       SCP STATION  ENTRIES    EXITS            DATETIME  \
# 1  A002  R051  02-00-00   59 ST  7511655  2558877 2021-01-02 07:00:00
# 2  A002  R051  02-00-00   59 ST  7511677  2558930 2021-01-02 11:00:00
# 3  A002  R051  02-00-00   59 ST  7511766  2558968 2021-01-02 15:00:00
# 4  A002  R051  02-00-00   59 ST  7511912  2558999 2021-01-02 19:00:00
# 5  A002  R051  02-00-00   59 ST  7511996  2559007 2021-01-02 23:00:00
#
#   DAY_OF_WEEK       PREV_DATETIME  PREV_ENTRIES  PREV_EXITS  entry_count  \
# 1    Saturday 2021-01-02 03:00:00     7511653.0   2558871.0          2.0
# 2    Saturday 2021-01-02 07:00:00     7511655.0   2558877.0         22.0
# 3    Saturday 2021-01-02 11:00:00     7511677.0   2558930.0         89.0
# 4    Saturday 2021-01-02 15:00:00     7511766.0   2558968.0        146.0
# 5    Saturday 2021-01-02 19:00:00     7511912.0   2558999.0         84.0
#
#    exit_count  ENTRY_DIFF  EXIT_DIFF  TOTAL_TRAFFIC
# 1         6.0         2.0        6.0            8.0
# 2        53.0        22.0       53.0           75.0
# 3        38.0        89.0       38.0          127.0
# 4        31.0       146.0       31.0          177.0
# 5         8.0        84.0        8.0           92.0

# %%
#Sanity Check
(df
 .groupby(['C/A','UNIT','SCP','STATION','DATETIME','DAY_OF_WEEK'])
 .sum()
 .reset_index())
# Out:
#          C/A  UNIT       SCP          STATION            DATETIME DAY_OF_WEEK  \
# 0       A002  R051  02-00-00            59 ST 2021-01-02 07:00:00    Saturday
# 1       A002  R051  02-00-00            59 ST 2021-01-02 11:00:00    Saturday
# 2       A002  R051  02-00-00            59 ST 2021-01-02 15:00:00    Saturday
# 3       A002  R051  02-00-00            59 ST 2021-01-02 19:00:00    Saturday
# 4       A002  R051  02-00-00            59 ST 2021-01-02 23:00:00    Saturday
# ...      ...   ...       ...              ...                 ...         ...
# 567552  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 04:00:00      Friday
# 567553  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 08:00:00      Friday
# 567554  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 12:00:00      Friday
# 567555  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 16:00:00      Friday
# 567556  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 20:00:00      Friday
#
#            ENTRIES       EXITS  PREV_ENTRIES    PREV_EXITS  entry_count  \
# 0          7511655     2558877  7.511653e+06  2.558871e+06          2.0
# 1          7511677     2558930  7.511655e+06  2.558877e+06         22.0
# 2          7511766     2558968  7.511677e+06  2.558930e+06         89.0
# 3          7511912     2558999  7.511766e+06  2.558968e+06        146.0
# 4          7511996     2559007  7.511912e+06  2.558999e+06         84.0
# ...            ...         ...           ...           ...          ...
# 567552  1559826404  1728238157  1.559826e+09  1.728238e+09          0.0
# 567553  1559826356  1728238172  1.559826e+09  1.728238e+09         48.0
# 567554  1559826324  1728238186  1.559826e+09  1.728238e+09         32.0
# 567555  1559826293  1728238195  1.559826e+09  1.728238e+09         31.0
# 567556  1559826268  1728238235  1.559826e+09  1.728238e+09         25.0
#
#         exit_count  ENTRY_DIFF  EXIT_DIFF  TOTAL_TRAFFIC
# 0              6.0         2.0        6.0            8.0
# 1             53.0        22.0       53.0           75.0
# 2             38.0        89.0       38.0          127.0
# 3             31.0       146.0       31.0          177.0
# 4              8.0        84.0        8.0           92.0
# ...            ...         ...        ...            ...
# 567552         0.0         0.0        0.0            0.0
# 567553        15.0        48.0       15.0           63.0
# 567554        14.0        32.0       14.0           46.0
# 567555         9.0        31.0        9.0           40.0
# 567556        40.0        25.0       40.0           65.0
#
# [567557 rows x 15 columns]

# %% [markdown]
# **3. Inconsistent time intervals**
#    - unifying into same time intervals (4-hours)

# %%
# Check TIME intervals
df['TIME'] = df['DATETIME'].apply(lambda x: x.time())
print(df.TIME.unique())
print(df.TIME.value_counts())
# Out:
# [datetime.time(7, 0) datetime.time(11, 0) datetime.time(15, 0)
#  datetime.time(19, 0) datetime.time(23, 0) datetime.time(3, 0)
#  datetime.time(5, 0) datetime.time(9, 0) datetime.time(13, 0)
#  datetime.time(17, 0) datetime.time(21, 0) datetime.time(1, 0)
#  datetime.time(17, 14, 50) datetime.time(17, 16, 10)
#  datetime.time(17, 17, 31) datetime.time(17, 18, 51)
#  datetime.time(17, 20, 12) datetime.time(17, 21, 33)
#  datetime.time(17, 22, 53) datetime.time(17, 24, 13)
#  datetime.time(17, 25, 34) datetime.time(17, 26, 55)
#  datetime.time(17, 28, 15) datetime.time(17, 29, 36)
#  datetime.time(17, 30, 56) datetime.time(17, 32, 17)
#  datetime.time(17, 33, 38) datetime.time(4, 0) datetime.time(8, 0)
#  datetime.time(12, 0) datetime.time(16, 0) datetime.time(20, 0)
#  datetime.time(0, 0) datetime.time(16, 8, 52) datetime.time(16, 5, 55)
#  datetime.time(20, 37, 45) datetime.time(20, 38, 55)
#  datetime.time(8, 4, 29) datetime.time(8, 5, 39) datetime.time(6, 0)
#  datetime.time(10, 0) datetime.time(14, 0) datetime.time(18, 0)
#  datetime.time(22, 0) datetime.time(2, 0) datetime.time(3, 26, 13)
#  datetime.time(3, 27, 14) datetime.time(3, 28, 27)
#  datetime.time(3, 29, 33) datetime.time(3, 30, 35)
#  datetime.time(19, 27, 1) datetime.time(9, 12, 3) datetime.time(9, 23, 39)
#  datetime.time(8, 7, 31) datetime.time(19, 12, 7) datetime.time(19, 3, 32)
#  datetime.time(19, 5, 5) datetime.time(5, 1, 47) datetime.time(18, 31, 27)
#  datetime.time(18, 32, 48) datetime.time(18, 34, 8)
#  datetime.time(18, 35, 28) datetime.time(18, 36, 50)
#  datetime.time(18, 38, 11) datetime.time(18, 39, 31)
#  datetime.time(9, 22, 34) datetime.time(9, 23, 19)
#  datetime.time(10, 39, 59) datetime.time(10, 41, 32)
#  datetime.time(21, 22, 10) datetime.time(9, 21, 48)
#  datetime.time(19, 47, 14) datetime.time(5, 2, 39) datetime.time(5, 3, 58)
#  datetime.time(5, 5, 19) datetime.time(5, 6, 39) datetime.time(5, 7, 59)
#  datetime.time(5, 9, 19) datetime.time(5, 10, 39) datetime.time(5, 11, 59)
#  datetime.time(5, 13, 19) datetime.time(5, 14, 39)
#  datetime.time(5, 15, 45) datetime.time(5, 17, 5) datetime.time(5, 18, 39)
#  datetime.time(5, 19, 59) datetime.time(5, 21, 20)
#  datetime.time(5, 22, 40) datetime.time(5, 24) datetime.time(5, 25, 20)
#  datetime.time(5, 26, 40) datetime.time(5, 28) datetime.time(5, 29, 20)
#  datetime.time(5, 30, 40) datetime.time(5, 32) datetime.time(5, 33, 20)
#  datetime.time(5, 1, 18) datetime.time(9, 23, 44) datetime.time(9, 23, 29)
#  datetime.time(14, 34, 8) datetime.time(5, 26, 2) datetime.time(3, 31, 11)
#  datetime.time(7, 39, 13) datetime.time(7, 40, 33)
#  datetime.time(7, 41, 53) datetime.time(7, 43, 13)
#  datetime.time(7, 44, 33) datetime.time(7, 45, 53)
#  datetime.time(7, 47, 13) datetime.time(7, 48, 34)
#  datetime.time(7, 49, 54) datetime.time(7, 51, 14)
#  datetime.time(7, 52, 34) datetime.time(7, 53, 54)
#  datetime.time(7, 55, 14) datetime.time(7, 22) datetime.time(11, 22)
#  datetime.time(15, 22) datetime.time(19, 22) datetime.time(23, 22)
#  datetime.time(3, 22) datetime.time(17, 3, 54) datetime.time(17, 6, 40)
#  datetime.time(17, 8, 1) datetime.time(17, 9, 20) datetime.time(17, 5, 3)
#  datetime.time(17, 10, 40) datetime.time(17, 12) datetime.time(17, 13, 20)
#  datetime.time(17, 14, 40) datetime.time(17, 16) datetime.time(17, 17, 20)
#  datetime.time(17, 18, 42) datetime.time(17, 20, 2)
#  datetime.time(17, 21, 20) datetime.time(17, 22, 40)
#  datetime.time(4, 58, 8) datetime.time(4, 59, 28) datetime.time(5, 0, 48)
#  datetime.time(5, 2, 8) datetime.time(5, 3, 28) datetime.time(5, 4, 48)
#  datetime.time(5, 6, 8) datetime.time(5, 7, 28) datetime.time(5, 8, 48)
#  datetime.time(5, 10, 9) datetime.time(5, 11, 29) datetime.time(5, 12, 49)
#  datetime.time(5, 14, 9) datetime.time(5, 15, 29) datetime.time(5, 16, 49)
#  datetime.time(5, 18, 29) datetime.time(5, 19, 51)
#  datetime.time(5, 21, 12) datetime.time(5, 22, 31)
#  datetime.time(5, 23, 51) datetime.time(5, 25, 57)
#  datetime.time(5, 27, 17) datetime.time(5, 28, 37)
#  datetime.time(5, 29, 57) datetime.time(5, 31, 17) datetime.time(5, 50)
#  datetime.time(5, 51, 21) datetime.time(5, 52, 41) datetime.time(5, 54, 1)
#  datetime.time(5, 55, 21) datetime.time(5, 56, 41) datetime.time(5, 58, 1)
#  datetime.time(5, 59, 21) datetime.time(6, 0, 41) datetime.time(6, 2, 1)
#  datetime.time(20, 34, 45) datetime.time(1, 28, 47) datetime.time(1, 30)
#  datetime.time(5, 30) datetime.time(5, 38, 59) datetime.time(5, 40, 19)
#  datetime.time(5, 41, 39) datetime.time(5, 42, 59)
#  datetime.time(5, 44, 20) datetime.time(5, 45, 40) datetime.time(5, 47)
#  datetime.time(5, 48, 20) datetime.time(9, 30) datetime.time(13, 30)
#  datetime.time(17, 30) datetime.time(21, 30) datetime.time(4, 56, 2)
#  datetime.time(4, 57, 22) datetime.time(4, 58, 42) datetime.time(5, 0, 2)
#  datetime.time(5, 1, 23) datetime.time(5, 2, 42) datetime.time(5, 4, 3)
#  datetime.time(5, 5, 23) datetime.time(5, 6, 43) datetime.time(5, 7, 48)
#  datetime.time(5, 9, 8) datetime.time(5, 10, 29) datetime.time(5, 11, 49)
#  datetime.time(5, 13, 9) datetime.time(5, 14, 29) datetime.time(5, 15, 49)
#  datetime.time(5, 17, 9) datetime.time(5, 19, 49) datetime.time(5, 21, 24)
#  datetime.time(5, 22, 44) datetime.time(5, 24, 4) datetime.time(4, 40, 50)
#  datetime.time(4, 42, 10) datetime.time(4, 43, 30)
#  datetime.time(4, 44, 50) datetime.time(4, 46, 11)
#  datetime.time(4, 47, 31) datetime.time(4, 48, 51)
#  datetime.time(4, 50, 11) datetime.time(4, 51, 31)
#  datetime.time(4, 52, 51) datetime.time(4, 54, 11)
#  datetime.time(4, 55, 31) datetime.time(4, 56, 51) datetime.time(5, 2, 5)
#  datetime.time(5, 3, 25) datetime.time(5, 4, 45) datetime.time(5, 6, 5)
#  datetime.time(5, 7, 25) datetime.time(5, 8, 45) datetime.time(5, 10, 5)
#  datetime.time(5, 11, 25) datetime.time(5, 12, 46) datetime.time(5, 14, 6)
#  datetime.time(5, 15, 26) datetime.time(5, 16, 46) datetime.time(5, 18, 6)
#  datetime.time(5, 19, 26) datetime.time(5, 20, 46) datetime.time(5, 22, 6)
#  datetime.time(5, 23, 26) datetime.time(5, 9, 6) datetime.time(5, 10, 26)
#  datetime.time(5, 11, 46) datetime.time(5, 13, 7) datetime.time(5, 14, 27)
#  datetime.time(5, 15, 47) datetime.time(5, 17, 7) datetime.time(5, 18, 27)
#  datetime.time(5, 19, 47) datetime.time(5, 21, 7) datetime.time(5, 22, 27)
#  datetime.time(5, 23, 47) datetime.time(5, 25, 7) datetime.time(5, 26, 28)
#  datetime.time(5, 27, 48) datetime.time(5, 29, 8) datetime.time(5, 32, 44)
#  datetime.time(5, 34, 4) datetime.time(5, 35, 24) datetime.time(5, 36, 44)
#  datetime.time(5, 38, 4) datetime.time(5, 39, 24)
#  datetime.time(18, 26, 40) datetime.time(21, 13, 41)
#  datetime.time(6, 18, 48) datetime.time(6, 20, 8) datetime.time(6, 21, 28)
#  datetime.time(6, 22, 48) datetime.time(6, 24, 8) datetime.time(6, 25, 28)
#  datetime.time(6, 26, 49) datetime.time(6, 30, 49) datetime.time(6, 32, 9)
#  datetime.time(6, 33, 29) datetime.time(6, 34, 49) datetime.time(6, 36, 9)
#  datetime.time(6, 37, 29) datetime.time(6, 38, 49) datetime.time(6, 40, 9)
#  datetime.time(6, 41, 29) datetime.time(6, 42, 49)
#  datetime.time(6, 44, 10) datetime.time(6, 45, 30)
#  datetime.time(6, 46, 50) datetime.time(6, 48, 10)
#  datetime.time(6, 49, 30) datetime.time(6, 50, 50)
#  datetime.time(6, 52, 10) datetime.time(6, 53, 31)
#  datetime.time(6, 54, 50) datetime.time(6, 56, 11)
#  datetime.time(9, 23, 33) datetime.time(6, 28, 9) datetime.time(6, 29, 29)
#  datetime.time(20, 59, 22) datetime.time(22, 37, 24)
#  datetime.time(12, 51, 48) datetime.time(22, 23, 44)
#  datetime.time(22, 37, 57) datetime.time(22, 43, 28)
#  datetime.time(16, 56, 33) datetime.time(7, 30) datetime.time(11, 30)
#  datetime.time(15, 30) datetime.time(19, 30) datetime.time(23, 30)
#  datetime.time(3, 30) datetime.time(9, 23, 58) datetime.time(9, 25, 20)
#  datetime.time(21, 33, 1) datetime.time(21, 34, 26)
#  datetime.time(9, 23, 48) datetime.time(14, 14, 14)
#  datetime.time(14, 15, 18) datetime.time(14, 28, 7)
#  datetime.time(14, 29, 11) datetime.time(14, 30, 27)
#  datetime.time(4, 40, 22) datetime.time(4, 41, 42) datetime.time(4, 43, 2)
#  datetime.time(4, 44, 22) datetime.time(4, 45, 42) datetime.time(4, 47, 2)
#  datetime.time(4, 49, 42) datetime.time(4, 55, 3) datetime.time(4, 56, 23)
#  datetime.time(4, 57, 43) datetime.time(4, 59, 3) datetime.time(5, 1, 50)
#  datetime.time(5, 3, 11) datetime.time(5, 4, 31) datetime.time(5, 5, 51)
#  datetime.time(5, 7, 11) datetime.time(5, 8, 31) datetime.time(5, 9, 51)
#  datetime.time(5, 11, 11) datetime.time(5, 12, 32)
#  datetime.time(5, 13, 52) datetime.time(5, 15, 12)
#  datetime.time(5, 16, 32) datetime.time(5, 17, 52) datetime.time(5, 9, 17)
#  datetime.time(5, 10, 37) datetime.time(5, 11, 58)
#  datetime.time(5, 13, 18) datetime.time(5, 14, 38)
#  datetime.time(5, 15, 58) datetime.time(5, 17, 18)
#  datetime.time(5, 18, 38) datetime.time(5, 19, 58)
#  datetime.time(5, 21, 18) datetime.time(5, 22, 38)
#  datetime.time(5, 23, 58) datetime.time(5, 25, 19)
#  datetime.time(5, 26, 39) datetime.time(5, 27, 59) datetime.time(5, 32, 5)
#  datetime.time(5, 33, 25) datetime.time(5, 34, 45) datetime.time(5, 36, 5)
#  datetime.time(5, 37, 25) datetime.time(5, 38, 45) datetime.time(5, 40, 5)
#  datetime.time(5, 41, 26) datetime.time(5, 42, 46) datetime.time(5, 44, 6)
#  datetime.time(5, 45, 26) datetime.time(5, 46, 46) datetime.time(5, 48, 6)
#  datetime.time(5, 49, 26) datetime.time(5, 50, 46) datetime.time(5, 52, 6)
#  datetime.time(5, 53, 26) datetime.time(5, 54, 46) datetime.time(5, 56, 6)
#  datetime.time(5, 57, 26) datetime.time(5, 58, 46) datetime.time(6, 0, 7)
#  datetime.time(6, 1, 27) datetime.time(6, 2, 47) datetime.time(6, 4, 7)
#  datetime.time(6, 5, 27) datetime.time(6, 6, 47) datetime.time(6, 8, 7)
#  datetime.time(6, 9, 28) datetime.time(4, 51, 2) datetime.time(4, 52, 22)
#  datetime.time(4, 53, 42) datetime.time(5, 0, 23)
#  datetime.time(21, 39, 30) datetime.time(11, 3, 11)
#  datetime.time(11, 4, 39) datetime.time(4, 0, 1) datetime.time(21, 18, 51)
#  datetime.time(20, 58, 41) datetime.time(21, 3, 48)
#  datetime.time(21, 7, 23) datetime.time(21, 13, 33)
#  datetime.time(21, 14, 54) datetime.time(17, 59, 11)
#  datetime.time(10, 49, 38) datetime.time(12, 57, 1)
#  datetime.time(13, 20, 49) datetime.time(21, 16, 59)
#  datetime.time(21, 23, 29) datetime.time(10, 50, 55)
#  datetime.time(10, 52, 1) datetime.time(10, 53, 13)
#  datetime.time(10, 55, 37) datetime.time(7, 50, 5)
#  datetime.time(9, 23, 25) datetime.time(5, 38, 6)
#  datetime.time(17, 40, 22) datetime.time(17, 41, 43)
#  datetime.time(17, 42, 50) datetime.time(17, 43, 59)
#  datetime.time(17, 35, 21) datetime.time(17, 37, 47)
#  datetime.time(17, 39, 15) datetime.time(21, 2, 54)
#  datetime.time(21, 3, 59) datetime.time(21, 5, 1) datetime.time(16, 7, 27)
#  datetime.time(22, 24, 11) datetime.time(22, 25, 31)
#  datetime.time(22, 26, 52) datetime.time(22, 28, 13)
#  datetime.time(22, 29, 35) datetime.time(22, 30, 54)
#  datetime.time(22, 32, 14) datetime.time(22, 33, 35)
#  datetime.time(22, 34, 55) datetime.time(22, 36, 16)
#  datetime.time(22, 37, 37) datetime.time(9, 22, 47)
#  datetime.time(18, 50, 36) datetime.time(18, 51, 56)
#  datetime.time(18, 53, 16) datetime.time(7, 57, 52)
#  datetime.time(15, 43, 7) datetime.time(17, 16, 7)
#  datetime.time(17, 17, 28) datetime.time(13, 42, 20)
#  datetime.time(13, 43, 23) datetime.time(13, 44, 28)
#  datetime.time(13, 45, 29) datetime.time(13, 46, 29)
#  datetime.time(13, 47, 42) datetime.time(13, 48, 44)
#  datetime.time(13, 49, 48) datetime.time(13, 51, 9)
#  datetime.time(13, 52, 10) datetime.time(13, 53, 11)
#  datetime.time(13, 54, 11) datetime.time(13, 55, 11)
#  datetime.time(13, 57, 12) datetime.time(13, 58, 13)
#  datetime.time(13, 59, 14) datetime.time(14, 0, 14)
#  datetime.time(14, 1, 15) datetime.time(14, 2, 15)
#  datetime.time(14, 4, 17) datetime.time(14, 5, 17)
#  datetime.time(14, 6, 18) datetime.time(14, 7, 19)
#  datetime.time(14, 8, 19) datetime.time(14, 9, 20)
#  datetime.time(14, 10, 20) datetime.time(14, 12, 28)
#  datetime.time(14, 13, 28) datetime.time(14, 14, 29)
#  datetime.time(14, 15, 29) datetime.time(14, 16, 30)
#  datetime.time(14, 17, 30) datetime.time(14, 18, 33)
#  datetime.time(14, 21, 35) datetime.time(14, 23, 36)
#  datetime.time(14, 24, 36) datetime.time(14, 25, 37)
#  datetime.time(14, 26, 37) datetime.time(14, 27, 38)
#  datetime.time(14, 28, 38) datetime.time(14, 29, 39)
#  datetime.time(14, 30, 40) datetime.time(14, 31, 40)
#  datetime.time(14, 32, 41) datetime.time(14, 33, 42)
#  datetime.time(14, 34, 48) datetime.time(14, 35, 49)
#  datetime.time(14, 36, 49) datetime.time(14, 37, 50)
#  datetime.time(14, 38, 50) datetime.time(14, 39, 51)
#  datetime.time(14, 40, 52) datetime.time(14, 41, 55)
#  datetime.time(14, 42, 56) datetime.time(14, 43, 57)
#  datetime.time(14, 44, 57) datetime.time(14, 45, 59)
#  datetime.time(14, 46, 59) datetime.time(14, 48) datetime.time(14, 49)
#  datetime.time(14, 53, 9) datetime.time(14, 54, 11)
#  datetime.time(14, 55, 12) datetime.time(14, 56, 13)
#  datetime.time(14, 57, 20) datetime.time(14, 58, 23)
#  datetime.time(14, 59, 30) datetime.time(15, 0, 32)
#  datetime.time(15, 1, 34) datetime.time(15, 2, 51)
#  datetime.time(15, 3, 52) datetime.time(15, 4, 54)
#  datetime.time(15, 6, 11) datetime.time(15, 7, 12)
#  datetime.time(15, 8, 14) datetime.time(15, 9, 33)
#  datetime.time(15, 10, 54) datetime.time(15, 12, 14)
#  datetime.time(15, 13, 34) datetime.time(15, 14, 54)
#  datetime.time(15, 16, 14) datetime.time(15, 17, 34)
#  datetime.time(15, 18, 55) datetime.time(15, 20, 15)
#  datetime.time(15, 21, 35) datetime.time(15, 22, 55)
#  datetime.time(15, 24, 15) datetime.time(15, 25, 36)
#  datetime.time(15, 26, 56) datetime.time(15, 28, 16)
#  datetime.time(15, 29, 37) datetime.time(15, 30, 57)
#  datetime.time(15, 32, 19) datetime.time(15, 33, 39)
#  datetime.time(15, 35, 1) datetime.time(15, 36, 24)
#  datetime.time(15, 37, 44) datetime.time(15, 39, 5)
#  datetime.time(15, 40, 26) datetime.time(15, 41, 46)
#  datetime.time(15, 44, 28) datetime.time(15, 45, 49)
#  datetime.time(15, 47, 9) datetime.time(15, 48, 29)
#  datetime.time(15, 49, 49) datetime.time(15, 51, 10)
#  datetime.time(15, 52, 30) datetime.time(15, 53, 50)
#  datetime.time(15, 55, 10) datetime.time(15, 56, 31)
#  datetime.time(15, 57, 51) datetime.time(15, 59, 11)
#  datetime.time(16, 0, 31) datetime.time(16, 1, 51)
#  datetime.time(16, 3, 11) datetime.time(16, 4, 31)
#  datetime.time(16, 5, 51) datetime.time(16, 7, 11)
#  datetime.time(16, 8, 32) datetime.time(16, 9, 52)
#  datetime.time(16, 11, 12) datetime.time(16, 12, 32)
#  datetime.time(16, 13, 52) datetime.time(16, 15, 14)
#  datetime.time(16, 16, 34) datetime.time(16, 17, 55)
#  datetime.time(16, 19, 15) datetime.time(16, 20, 35)
#  datetime.time(16, 21, 55) datetime.time(16, 23, 15)
#  datetime.time(16, 24, 35) datetime.time(16, 25, 55)
#  datetime.time(16, 27, 16) datetime.time(5, 27, 33)
#  datetime.time(9, 23, 14) datetime.time(23, 37, 20)
#  datetime.time(23, 38, 40) datetime.time(23, 40) datetime.time(23, 41, 20)
#  datetime.time(23, 42, 40) datetime.time(23, 45, 20)
#  datetime.time(23, 46, 40) datetime.time(23, 48, 1)
#  datetime.time(23, 49, 21) datetime.time(23, 50, 41)
#  datetime.time(23, 52, 1) datetime.time(23, 53, 21)
#  datetime.time(23, 54, 41) datetime.time(23, 56, 1)
#  datetime.time(21, 21, 47) datetime.time(23, 44) datetime.time(16, 19, 34)
#  datetime.time(16, 25, 44) datetime.time(9, 23, 3)
#  datetime.time(15, 42, 55) datetime.time(3, 57, 43)
#  datetime.time(3, 59, 3) datetime.time(4, 0, 23) datetime.time(4, 1, 43)
#  datetime.time(4, 3, 3) datetime.time(4, 4, 24) datetime.time(4, 5, 44)
#  datetime.time(4, 7, 4) datetime.time(4, 8, 24) datetime.time(4, 9, 44)
#  datetime.time(4, 11, 44) datetime.time(4, 13, 4) datetime.time(4, 14, 24)
#  datetime.time(4, 15, 44) datetime.time(4, 17, 4) datetime.time(4, 18, 25)
#  datetime.time(4, 19, 45) datetime.time(4, 21, 5) datetime.time(4, 22, 25)
#  datetime.time(4, 23, 45)]
# 19:00:00    52205
# 15:00:00    52096
# 11:00:00    52077
# 23:00:00    52067
# 07:00:00    52038
#             ...
# 13:52:10        1
# 14:30:40        1
# 14:31:40        1
# 14:44:57        1
# 14:27:38        1
# Name: TIME, Length: 615, dtype: int64

# %%
# Turn all time intervals to 4-hour frequency
df = df.groupby(['C/A', 'UNIT', 'SCP', 'STATION',
                  pd.Grouper(key='DATETIME', freq='4H'),
                  'DAY_OF_WEEK', 'TIME']).sum().reset_index()
# Double checking on time intervals
df['TIME'] = df['DATETIME'].apply(lambda x: x.time())
print(df.TIME.unique())
# Out:
# [datetime.time(4, 0) datetime.time(8, 0) datetime.time(12, 0)
#  datetime.time(16, 0) datetime.time(20, 0) datetime.time(0, 0)]

# %%
# Syncing Day_of_week column to the new datetime
df['DAY_OF_WEEK'] = (df['DATETIME']
                    .apply(lambda x : datetime.strftime(x, "%A")))

# %%
#Sanity Check
(df
 .groupby(['C/A','UNIT','SCP','STATION','DATETIME','DAY_OF_WEEK'])
 .sum()
 .reset_index())
# Out:
#          C/A  UNIT       SCP          STATION            DATETIME DAY_OF_WEEK  \
# 0       A002  R051  02-00-00            59 ST 2021-01-02 04:00:00    Saturday
# 1       A002  R051  02-00-00            59 ST 2021-01-02 08:00:00    Saturday
# 2       A002  R051  02-00-00            59 ST 2021-01-02 12:00:00    Saturday
# 3       A002  R051  02-00-00            59 ST 2021-01-02 16:00:00    Saturday
# 4       A002  R051  02-00-00            59 ST 2021-01-02 20:00:00    Saturday
# ...      ...   ...       ...              ...                 ...         ...
# 562958  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 04:00:00      Friday
# 562959  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 08:00:00      Friday
# 562960  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 12:00:00      Friday
# 562961  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 16:00:00      Friday
# 562962  R730  R431  00-00-04  EASTCHSTER/DYRE 2021-01-22 20:00:00      Friday
#
#            ENTRIES       EXITS  PREV_ENTRIES    PREV_EXITS  entry_count  \
# 0          7511655     2558877  7.511653e+06  2.558871e+06          2.0
# 1          7511677     2558930  7.511655e+06  2.558877e+06         22.0
# 2          7511766     2558968  7.511677e+06  2.558930e+06         89.0
# 3          7511912     2558999  7.511766e+06  2.558968e+06        146.0
# 4          7511996     2559007  7.511912e+06  2.558999e+06         84.0
# ...            ...         ...           ...           ...          ...
# 562958  1559826404  1728238157  1.559826e+09  1.728238e+09          0.0
# 562959  1559826356  1728238172  1.559826e+09  1.728238e+09         48.0
# 562960  1559826324  1728238186  1.559826e+09  1.728238e+09         32.0
# 562961  1559826293  1728238195  1.559826e+09  1.728238e+09         31.0
# 562962  1559826268  1728238235  1.559826e+09  1.728238e+09         25.0
#
#         exit_count  ENTRY_DIFF  EXIT_DIFF  TOTAL_TRAFFIC
# 0              6.0         2.0        6.0            8.0
# 1             53.0        22.0       53.0           75.0
# 2             38.0        89.0       38.0          127.0
# 3             31.0       146.0       31.0          177.0
# 4              8.0        84.0        8.0           92.0
# ...            ...         ...        ...            ...
# 562958         0.0         0.0        0.0            0.0
# 562959        15.0        48.0       15.0           63.0
# 562960        14.0        32.0       14.0           46.0
# 562961         9.0        31.0        9.0           40.0
# 562962        40.0        25.0       40.0           65.0
#
# [562963 rows x 15 columns]

# %%
# Final clean up
# Drop unnecessary columns
turnstile_df = df.drop(['C/A', 'UNIT', 'SCP',
                         'ENTRIES', 'EXITS', 'TIME',
                         'PREV_ENTRIES', 'PREV_EXITS', 
                         'entry_count', 'exit_count'], axis=1)
turnstile_df.head()
# Out:
#   STATION            DATETIME DAY_OF_WEEK  ENTRY_DIFF  EXIT_DIFF  \
# 0   59 ST 2021-01-02 04:00:00    Saturday         2.0        6.0
# 1   59 ST 2021-01-02 08:00:00    Saturday        22.0       53.0
# 2   59 ST 2021-01-02 12:00:00    Saturday        89.0       38.0
# 3   59 ST 2021-01-02 16:00:00    Saturday       146.0       31.0
# 4   59 ST 2021-01-02 20:00:00    Saturday        84.0        8.0
#
#    TOTAL_TRAFFIC
# 0            8.0
# 1           75.0
# 2          127.0
# 3          177.0
# 4           92.0

# %%
#Save file as csv
#turnstile_df.to_csv('./data/cleaned_mta_df.csv')
